# %%
from detection import *
import cv2
import matplotlib.pyplot as plt

DIR = r"../data/5.png"
frame =  detect_persons_and_phones(frame=DIR)


def draw_detections(frame, detections):
    for (x, y, w, h), conf, label in detections:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
        label_text = f"{label} {conf:.2f}"
        cv2.putText(frame, label_text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX,
                    0.6, (0, 255, 0), 2)
    return frame


image_path = DIR  # Change to your image path
img = cv2.imread(image_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
annotated_img = draw_detections(img.copy(), frame)
annotated_img_rgb = cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 8))
plt.imshow(annotated_img_rgb)
plt.axis("off")
plt.title("Human Detection (YOLOv8)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 annotated_img = draw_detections(img.copy(), frame)
#       2 annotated_img_rgb = cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB)
#       4 plt.figure(figsize=(10, 8))
#
# Cell In[2], line 10, in draw_detections(frame, detections)
#       9 def draw_detections(frame, detections):
# ---> 10     for (x, y, w, h), conf, label in detections:
#      11         cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
#      12         label_text = f"{label} {conf:.2f}"
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
from ultralytics import NAS

model = NAS("yolo_nas_s.pt")
results = model("/mnt/01DBD18E2F423170/Development/NoleTrano/data/2.png")
# Out:
# [2025-06-27 10:58:12] INFO - crash_tips_setup.py - Crash tips is enabled. You can set your environment variable to CRASH_HANDLER=FALSE to disable it
# The console stream is logged into /home/phuong5569/sg_logs/console.log
#
# image 1/1 /mnt/01DBD18E2F423170/Development/NoleTrano/data/2.png: 448x640 9 persons, 1 tie, 101.5ms
# Speed: 6.1ms preprocess, 101.5ms inference, 75.5ms postprocess per image at shape (1, 3, 448, 640)

# %%
results.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 results.show()
#
# AttributeError: 'list' object has no attribute 'show'
